# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ![Iris measures]
# (http://classes.cs.uoregon.edu/18F/cis199ids/pics/iris.png)

# %%
path = 'http://classes.cs.uoregon.edu/18F/cis199ids/data/'
file = path + 'iris.csv'
iris_df = pd.read_csv(file)
iris_df.shape
# Out:
# (150, 5)

# %%
iris_df.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# How many iris species are there?

# %%
iris_df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# Pair Plots

# %%
import seaborn as sns

# %%
sns.pairplot(iris_df, hue='Species', size=2.5)

# %% [markdown]
# Split 1: data into Features (X) and Targets (y)

# %%
X_iris = iris_df.drop('Species', axis=1) #drop the "Species" column
X_iris.shape
# Out:
# (150, 4)

# %%
y_iris = iris_df["Species"]
y_iris.shape
# Out:
# (150,)

# %% [markdown]
# Splut 2: X, y into Train and Test data

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_iris, y_iris, test_size=0.30, random_state=199)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %% [markdown]
# Explore, Clean X_train features data

# %%
#nothing to do right now

# %% [markdown]
# Clean X_test feature data the same way

# %%
#Not needed for iris data

# %% [markdown]
# Train Bayes model with training data

# %%
from sklearn.naive_bayes import GaussianNB #1. Choose model class
model = GaussianNB( )                      #2. Create an instance of the model class
#                                          #   AKA "instantiate" the model
model.fit(X_train, y_train)                #3. Train the model by fitting it to training features and targets
#.fit trains the model
# Out:
# GaussianNB(priors=None)

# %% [markdown]
# Predict test tagert using model with test features

# %%
y_predictions = model.predict(X_test) #4. Run the trained model on 
y_predictions.shape
# Out:
# (45,)

# %% [markdown]
# Check model accuracy

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_predictions)
# Out:
# 0.9333333333333333

# %% [markdown]
# This is a 93% accuracy rating... very good
